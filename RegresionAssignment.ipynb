# %% [markdown]
# # Regression Models

# %% [markdown]
# ## Goals
#
# In this Assignmnet :
#
#  - You Will impliment the regression models

# %% [markdown]
# ## Tools
# In this lab we will make use of:
# - NumPy, a popular library for scientific computing
# - Matplotlib, a popular library for plotting data
# - Pandas,  a Python library for data analysis

# %% [markdown]
# ### Import Libraries
#
# ![Libraries](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Libraries.png?raw=true)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %% [markdown]
# ###  Fetch Data From CSV Files
#
# ![Load Data](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Load%20N%20show.png?raw=true)

# %%
#Your code Here
#Read the trainig and testing data from the file
traindata = pd.read_csv('trainRegression.csv')# to read file
trd = traindata.head()

# %% [markdown]
# ### Show Data

# %%
#Your code Here
#Show the first 5 rows of the training data
print(trd)
# Out:
#       X       R
# 0  0.01 -0.2730
# 1  0.02 -0.1170
# 2  0.03 -0.3090
# 3  0.04  0.0306
# 4  0.05 -0.0802

# %% [markdown]
# ##### Expected Output
#
#
# ![Output 1](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/O1.png?raw=true)

# %% [markdown]
# ### Type Casting of Data
#
# ![TypeCasting](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Type%20Casting.png?raw=true)

# %%
#Your code Here
#TypeCast the data into numpy array

x_train = np.array(traindata['X'])#to store the X column data of training file in a numpy array
y_train = np.array(traindata['R'])#to store the R column data of training file in a numpy array
# print(x_train)
# print(y_train)

# %% [markdown]
# ### Plot Data

# %%
#Your code Here
#Plot your Training Data using matplotlib

plt.plot(x_train,y_train)

plt.show()#to show graph

# %% [markdown]
# ##### Expected Output
#
#
# ![Model Equations](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/O2.png?raw=true)

# %% [markdown]
#  ### Fit Linear Regression Model (Training data)
#
#  As our linear Model was
#
# ![Cost Funtion](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Cost%20funtion1.png?raw=true
# )
#
# And using derivatives we transformed our model into 2 simultaneous equations
#
# ![Model Equations](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Linear%20Model%20Eqs.png?raw=true)
#
#
# Then converted it in matrix form
#
# ![Model Equations](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Linear%20Model.png?raw=true)
#
#
#
# NOTE :  Now you are required to compute values wihtout using foor loop on tarining data
# - HINT : Use numpy library for this purpose

# %%
#Your code Here
#For loop is not recommended in these cases, 
#use numpy functions to calculate the values of above variables in one line of code.
#Such as x.shape for number of rows, sum() for sum of all elements in x
#np.dot() or multiply suntion for square of x 
m = np.shape(x_train)#returns the rows
m_int = int(m[0])#it is touple so we convert it in to int for further calculations
sum_x = np.sum(x_train)#summation of x 
sum_x_square =np.sum(x_train**2) #summation of x square
sum_y = np.sum(y_train)#summation of y
sum_x_y = np.sum(x_train*y_train)#summation of x*y
matrixA = np.array([[m_int,sum_x],[sum_x,sum_x_square]])#for (A)required(given) matrix fornation
print('Matrix A       :')
print(matrixA)
print('Matrix B       :')
matrixB = np.array([[sum_y],[sum_x_y]])#for(B)required(given) matrix fornation
print(matrixB)
# Out:
# Matrix A       :
# [[ 283.0000000000  444.9500000000]
#  [ 444.9500000000  932.7465000000]]
# Matrix B       :
# [[ 1.3908700000]
#  [-126.6414295000]]

# %% [markdown]
# Expected output
#
# ![Linear Model MAtrixes](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Matrixs%20Linear.png?raw=true)

# %%
#Your code Here
#Calculate the values of 0_node and 0_1 using Matrix Multiplication
#Hint: Use X = A^-1 * B to calculate the values of 0_node and 0_1
inverse= np.linalg.inv(matrixA)#use numpy functionality to find inverse
values = np.dot(inverse,matrixB)#use e numpy functionality to find vales of theta and theta1
print("Matrix X for the linear model")
print()
print(values)
# Out:
# Matrix X for the linear model
#
# [[ 0.8736060962]
#  [-0.5525107433]]

# %% [markdown]
# Expected Output
#
# ![Linear Model MAtrixes](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Matrixs%20LinearT.png?raw=true)

# %% [markdown]
# ### Run Predictions (Testing data)

# %%
# Your code Here
# In order to calculate the pridicted values of y
# Use the formula y = 0_node + 0_1 * x
# _____DO NOT USE FOR LOOP_____
# instead Convert the column of test_x into numpy a 2 dimensional matrix
# then use matrix multiplication to calculate the predicted values of y
test_r = pd.read_csv("testRegression.csv")#to read  testregression file
x_test = np.array(test_r['X'])#to store the X column data of test file in numpy array
y_test = np.array(test_r['R'])#to store the R column data of test file in numpy array
xx = x_test.reshape(-1,1)# to convert it into 2d array 
O = values[0]# to get tehta value 
o1 = values[1]#to get theta1 value 
yt = np.dot(xx,o1)# their product ( 0_1 * x)
y_predicted  = O + yt #(0_node + 0_1 * x)

# %% [markdown]
# ### Mean Square Error

# %% [markdown]
# ![Cost Funtion](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Cost%20funtion1.png?raw=true
# )

# %%
#Your code Here
#Using cost function calculate the cost of the model
m = np.shape(x_test)# to get rows 
int_mm = int(m[0])# convert into int 
y_actual = y_test
mean_square = np.dot(y_actual-y_predicted,y_actual-y_predicted)*(1/int_mm)# formula to find msq
print("Mean Square Error for LINEAR MODEL is ::",mean_square)
# Out:
# Mean Square Error for LINEAR MODEL is :: 0.3159321720459774

# %% [markdown]
# Expected Output
#
# ![MSE of Linear](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/MSE%20Linear.png?raw=true
# )

# %% [markdown]
# ### Plot Data (Train and Test Data)

# %%
##Your code Here
#Plot the predicted values of y against the test_x
plt.scatter(x_train,y_train,color='purple')# to draw scatter plot
plt.plot(x_test,y_predicted,color='red')# to draw linear  regression line
plt.xlabel('X_axis')# just for representation of x axis
plt.ylabel('Y_axis')# just for representation of y axis
print('linear Model for train Data')
plt.show()
plt.scatter(x_test,y_test,color='purple')# to draw scatter plot
plt.plot(x_test,y_predicted,color='red')# to draw linear regression line 
plt.xlabel('X_axis')# just for representation of x axis
plt.ylabel('Y_axis')# just for representation of y axis
print('linear Model for testing Data')
plt.show()
# Out:
# linear Model for train Data
# linear Model for testing Data

# %% [markdown]
# ### Expected Outputs for Linear Model
#
# ![Training Data Plot](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Linear%20O.png?raw=true)
#
# ![Test Data Plot](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Linear%20O%20test.png?raw=true)

# %% [markdown]
# ## Now Fit The Quadratic Model
#
#  As our Quadratic Model was
#
# ![Cost Funtion for quadratic ](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Cost%20funtion2.png?raw=true
# )
#
# And using derivatives we transformed our model into 3 simultaneous equations
#
# ![Model Equations of quadratic](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Quad%20Model%20Eqs.png?raw=true)
#
#
# Then converted it in matrix form
#
# ![Model Formula of Quadratic](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Quad%20Model1.png?raw=true)
#
#
#
# NOTE :  Now you are required to compute values wihtout using foor loop on tarining data
# - HINT : Use numpy library for this purpose

# %%
#Your code Here
#For loop is not recommended in these cases, 
#use numpy functions to calculate the values of above variables in one line of code.
#Such as x.shape for number of rows, sum() for sum of all elements in x
#np.dot() or multiply suntion for square of x 
m = np.shape(x_train)# to get rows
m_int = int(m[0])# to get int value
sum_x = np.sum(x_train)#summation of x 
sum_x_square =np.sum(x_train**2) #summation of x2
sum_x_cube = np.sum(x_train**3)#summation of x3
sum_x_tetra = np.sum(x_train**4)#summation of x4 
sum_y = np.sum(y_train)#summation of y 
sum_x_y = np.sum(x_train*y_train)#summation of x and y
sum_x_square_y = np.sum(y_train*x_train**2)#summation of y and x2
matrixA2 = np.array([[m_int,sum_x,sum_x_square],[sum_x,sum_x_square,sum_x_cube],[sum_x_square,sum_x_cube,sum_x_tetra]])#to create matrix A
print('Matrix A      :')
print(matrixA2)
print('Matrix B       :')
matrixB2 = np.array([[sum_y],[sum_x_y],[sum_x_square_y]])#to create matrix B 
print(matrixB2)
# Out:
# Matrix A      :
# [[ 283.0000000000  444.9500000000  932.7465000000]
#  [ 444.9500000000  932.7465000000  2199.7810250000]
#  [ 932.7465000000  2199.7810250000  5533.8525767700]]
# Matrix B       :
# [[ 1.3908700000]
#  [-126.6414295000]
#  [-378.8756895490]]

# %% [markdown]
# Expected Output

# %% [markdown]
# ![Quadratic Model Matrixes](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Matrixs%20Quad1.png?raw=true)

# %% [markdown]
# #### Compute Valus Of Three Θ`s

# %%
#Your code Here
#Calculate the values of 0_node and 0_1 using Matrix Multiplication
#Hint: Use X = A^-1 * B to calculate the values of 0_node , 0_1 and 0_2
inverse= np.linalg.inv(matrixA2)#use numpy functionality to find inverse
values = np.dot(inverse,matrixB2)#to find thetas values
print("Matrix X for the  model")
print()
print(values)
# Out:
# Matrix X for the  model
#
# [[ 1.1061145395]
#  [-0.9960659920]
#  [ 0.1410458452]]

# %% [markdown]
# Expected Output
#
# ![Quadratic Model MAtrixes](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Matrixs%20Quad.png?raw=true)

# %% [markdown]
# ### Run Predictions (Testing data)

# %%
# Your code Here
# In order to calculate the pridicted values of y
# Use the formula y = 0_node + 0_1 * x
# _____DO NOT USE FOR LOOP_____
# instead Convert the column of test_x into numpy a 2 dimensional matrix
# then use matrix multiplication to calculate the predicted values of y
test_r = pd.read_csv("testRegression.csv")
x_test = np.array(test_r['X'])#store column of X in numpy array
y_test = np.array(test_r['R'])#store column of R in numpy array
xx = x_test.reshape(-1,1)# for 2d dimesntion
# print(xx)
O = values[0]#0index 0
o1 = values[1]#access 1 index 0_1
o2 = values[2]#access 2 index 0_2
yt = np.dot(xx,o1)#their products
s1 = np.square(xx)#to get x2
yt2 = np.dot(s1,o2)#their product
y_predicted = O + yt+yt2 #for prediction( 0_node + 0_1 * x+ 0_2 * x**2)

# %% [markdown]
# ### Mean Square Error

# %% [markdown]
# ![Cost Funtion](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Cost%20funtion2.png?raw=true
# )

# %%
#Your code Here
#Using cost function calculate the cost of the model
m = np.shape(x_test)
int_mm = int(m[0])
y_actual = y_test
mean_square = np.dot(y_actual-y_predicted,y_actual-y_predicted)*(1/int_mm)
print("Mean Square Error for Quadratic MODEL is ::",mean_square)
# Out:
# Mean Square Error for LINEAR MODEL is :: 0.32604179594962857

# %% [markdown]
# Expected Output
#
# ![MSE of Quadratic](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/MSE%20Quad.png?raw=true
# )

# %% [markdown]
# ### Plot Data (Train and Test Data)

# %%
##Your code Here
#Plot the predicted values of y against the test_x
plt.scatter(x_train,y_train,color='purple')# to draw scatter graph
plt.plot(x_test,y_predicted,color='red')# to plot line fraph which shows the rl
plt.xlabel('X_axis')
plt.ylabel('Y_axis')
print('Model for train Data')
plt.show()
plt.scatter(x_test,y_test,color='purple')# to draw scatter graph
plt.plot(x_test,y_predicted,color='red')#to plot line fraph which shows the rl
plt.xlabel('X_axis')
plt.ylabel('Y_axis')
print('Model for testing Data')
plt.show()
# Out:
# Model for train Data
# Model for testing Data

# %% [markdown]
# ### Expected Outputs for Quadratic Model
#
# ![Training Data Plot](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Quad%20O.png?raw=true)
#
# ![Test Data Plot](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Quad%20O%20tets.png?raw=true)

# %% [markdown]
# ## Now Fit The Cubic Model
#
# Cubic Model in matrix form
#
# ![Model Formula of Quadratic](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Cubic%20Model.png?raw=true)
#
#
#
# NOTE :  Now you are required to compute values wihtout using foor loop on tarining data
# - HINT : Use numpy library for this purpose

# %%
#Your code Here
#For loop is not recommended in these cases, 
#use numpy functions to calculate the values of above variables in one line of code.
#Such as x.shape for number of rows, sum() for sum of all elements in x
#np.dot() or multiply suntion for square of x
# ALL PROCEDURES AS ABOVE NOW FOR CUBIC MODEL JUST
m_int = len(x_train)# to get of x
sum_x = np.sum(x_train) # summation of x
sum_x_square = np.sum(x_train ** 2)  # summation of x2
sum_x_cube = np.sum(x_train ** 3) # summation of x3
sum_x_tetra = np.sum(x_train ** 4) # summation of x4
sum_x_penta = np.sum(x_train ** 5)#summation of x5
sum_x_sixz = np.sum(x_train ** 6)#summation of x6
sum_y = np.sum(y_train)# #summation of y
sum_x_y = np.sum(x_train * y_train)#summation of x and y
sum_x_square_y = np.sum(y_train * (x_train ** 2))#summation of x2 and y
sum_x_cube_y = np.sum(y_train * (x_train ** 3))#summation of x3 and y

# Constructing matrices A and B
matrixA3 = np.array([[m_int, sum_x, sum_x_square, sum_x_cube],
                     [sum_x, sum_x_square, sum_x_cube, sum_x_tetra],
                     [sum_x_square, sum_x_cube, sum_x_tetra, sum_x_penta],
                     [sum_x_cube, sum_x_tetra, sum_x_penta, sum_x_sixz]])

matrixB3 = np.array([[sum_y], [sum_x_y], [sum_x_square_y], [sum_x_cube_y]]) 

print('Matrix A:')
print(matrixA3)
print('Matrix B:')
print(matrixB3)
# Out:
# Matrix A:
# [[ 283.0000000000  444.9500000000  932.7465000000  2199.7810250000]
#  [ 444.9500000000  932.7465000000  2199.7810250000  5533.8525767700]
#  [ 932.7465000000  2199.7810250000  5533.8525767700  14501.3382962825]
#  [ 2199.7810250000  5533.8525767700  14501.3382962825  39086.4884105844]]
# Matrix B:
# [[ 1.3908700000]
#  [-126.6414295000]
#  [-378.8756895490]
#  [-952.3241035315]]

# %% [markdown]
# Expected Output
#
# ![Cubic Model Matrixes](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Matrixs%20Cubic1.png?raw=true)

# %% [markdown]
# #### Compute Valus Of Four Θ`s

# %%
#Your code Here
#Calculate the values of 0_node and 0_1 using Matrix Multiplication
#Hint: Use X = A^-1 * B to calculate the values of 0_node , 0_1 ,0_2 and 0_3
inverse= np.linalg.inv(matrixA3)# functioanlity of numpy to inverse
values = np.dot(inverse,matrixB3)#A^-1 * B IMPLENTATION to get values of thetas
print("Matrix X for the  model")
print()
print(values)
# Out:
# Matrix X for the  model
#
# [[-0.1886263711]
#  [ 3.9407189528]
#  [-3.7825109528]
#  [ 0.8316614548]]

# %% [markdown]
# Expected Output
#
# ![Cubic Model MAtrixes](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Matrixs%20Cubic.png?raw=true)

# %% [markdown]
# ### Run Predictions (Testing data)

# %%
# Your code Here
# In order to calculate the pridicted values of y
# Use the formula y = 0_node + 0_1 * x
# _____DO NOT USE FOR LOOP_____
# instead Convert the column of test_x into numpy a 2 dimensional matrix
# then use matrix multiplication to calculate the predicted values of y
test_r = pd.read_csv("testRegression.csv")
x_test = np.array(test_r['X'])
y_test = np.array(test_r['R'])
xx = x_test.reshape(-1,1)
O = values[0]
o1 = values[1]
o2 = values[2]
o3 = values[3]# to get tehta 3 value
yt = np.dot(xx,o1)#product  0_1 * x
ss = np.square(xx)
yt2 = np.dot(ss,o2)# 0_2* x**2
cc = np.power(xx,3)
yt3 = np.dot(cc,o3)# 0_3 * x**3
y_predicted = O + yt + yt2 +yt3 #0_node + 0_1 * x+0_2 * x**2+0_3 * x**3

# %% [markdown]
# ### Mean Square Error

# %%
#Your code Here
#Using cost function calculate the cost of the model
m = np.shape(x_test)
int_mm = int(m[0])
y_actual = y_test
mean_square = np.dot(y_actual-y_predicted,y_actual-y_predicted)*(1/int_mm)
print("Mean Square Error for Cubic MODEL is ::",mean_square)
# Out:
# Mean Square Error for Cubic MODEL is :: 0.05154205769095602

# %% [markdown]
# Expected Output
#
# ![MSE of Cubic](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/MSE%20Cubic.png?raw=true
# )

# %% [markdown]
# ### Plot Data (Train and Test Data)

# %%
##Your code Here
#Plot the predicted values of y against the test_x
plt.scatter(x_train,y_train,color='pink')
plt.plot(x_test,y_predicted,color='red')
plt.xlabel('X_axis')
plt.ylabel('Y_axis')
print('Model for train Data')
plt.show()
plt.scatter(x_test,y_test,color='purple')
plt.plot(x_test,y_predicted,color='red')
plt.xlabel('X_axis')
plt.ylabel('Y_axis')
print(' Model for testing Data')
plt.show()
# Out:
# Model for train Data
#  Model for testing Data

# %% [markdown]
# ### Expected Outputs for Cubic Model
#
# ![Training Data Plot](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Cubic%20O.png?raw=true)
#
# ![Test Data Plot](https://github.com/ahmad-14a/CS-F20-ML/blob/main/Regression-Assignment%202/Cubic%20O%20test.png?raw=true)

# %% [markdown]
# ### Now You Are Required To Fit Your 4 , 5 and 6 degree Models Step By Step As You Did Before

# %% [markdown]
# ## Now Fit The 4 degree Model

# %%
m_int = len(x_train)#to get int no of x values 
sum_x = np.sum(x_train)#summation of x
sum_x_square = np.sum(x_train ** 2)#summation of x2
sum_x_cube = np.sum(x_train ** 3)#summation of x3
sum_x_tetra = np.sum(x_train ** 4)#summation of x4
sum_x_penta = np.sum(x_train ** 5)#summation of x5
sum_x_sixz = np.sum(x_train ** 6)#summation of x6
sum_x_sev = np.sum(x_train ** 7)#summation of x7
sum_x_eight = np.sum(x_train ** 8)#summation of x8
sum_y = np.sum(y_train)#summation of y
sum_x_y = np.sum(x_train * y_train)#summation of x and y
sum_x_square_y = np.sum(y_train * (x_train ** 2))#summation of x^2 and y
sum_x_cube_y = np.sum(y_train * (x_train ** 3))#summation of x^3 and y
sum_x_tetra_y = np.sum(y_train * (x_train ** 4))#summation of x^4 and y

# Constructing matrices A and B
matrixA4 = np.array([[m_int, sum_x, sum_x_square, sum_x_cube,sum_x_tetra],
                     [sum_x, sum_x_square, sum_x_cube, sum_x_tetra,sum_x_penta],
                     [sum_x_square, sum_x_cube, sum_x_tetra, sum_x_penta,sum_x_sixz],
                     [sum_x_cube, sum_x_tetra, sum_x_penta, sum_x_sixz,sum_x_sev],
                     [sum_x_tetra, sum_x_penta, sum_x_sixz,sum_x_sev,sum_x_eight]])

matrixB4 = np.array([[sum_y], [sum_x_y], [sum_x_square_y], [sum_x_cube_y],[sum_x_tetra_y]]) 

# matrices with desired to getrequired output to remove +e from numeric values 
np.set_printoptions(formatter={'float': '{: 0.10f}'.format})
print('Matrix A:')
print(matrixA4)
print('Matrix B:')
print(matrixB4)



#A^-1B
inverse= np.linalg.inv(matrixA4)#to find inverse
values = np.dot(inverse,matrixB4)#A^-1B
print("Matrix X for the model")
print()
print(values)#to print values 





test_r = pd.read_csv("testRegression.csv")# read csv fileof test data
x_test = np.array(test_r['X'])#store X column in numpy aray
y_test = np.array(test_r['R'])#store R column in numpy aray
xx = x_test.reshape(-1,1)# to convert into 2d dimension
O = values[0]# access 0index
o1 = values[1]# access 1 index 
o2 = values[2]# access 2 index 
o3 = values[3]# access 3 index 
o4 = values[4]# access 4 index 
yt = np.dot(xx,o1)#0_1 * x
ss = np.square(xx)#x^2
yt2 = np.dot(ss,o2)#0_2 * x^2
cc = np.power(xx,3)#x^3
yt3 = np.dot(cc,o3)#0_3 * x^3
tt = np.power(xx,4)#x^4
yt4 =np.dot(tt,o4)#0_4* x^4
y_predicted = O + yt + yt2 +yt3 +yt4# y= 0+0_1 * x+0_2 * x^2+0_3 * x^3+0_4 * x^4
m = np.shape(x_test)# to get the x len or u can say number of rows to get numbeer of x values
int_mm = int(m[0])# to get int of touple bcz shape function returns touple
y_actual = y_test
mean_square = np.dot(y_actual-y_predicted,y_actual-y_predicted)*(1/int_mm)#formula to find msq
print("Mean Square Error for 4Degree MODEL is ::",mean_square)

plt.scatter(x_train,y_train,color='pink')# to plot sactter graph of data
plt.plot(x_test,y_predicted,color='red')# to plot linear regression line
plt.xlabel('X_axis')#just to represent x axis
plt.ylabel('Y_axis')#just to represent y axis
print('Model for train Data')
plt.show()#to show graph
plt.scatter(x_test,y_test,color='purple')#to plot sactter graph of data
plt.plot(x_test,y_predicted,color='red')# to plot linear regression line
plt.xlabel('X_axis')#just to represent x axis
plt.ylabel('Y_axis')#just to represent y axis
print('Model for testing Data')
plt.show()#to show graph
# Out:
# Matrix A:
# [[ 283.0000000000  444.9500000000  932.7465000000  2199.7810250000
#    5533.8525767700]
#  [ 444.9500000000  932.7465000000  2199.7810250000  5533.8525767700
#    14501.3382962825]
#  [ 932.7465000000  2199.7810250000  5533.8525767700  14501.3382962825
#    39086.4884105844]
#  [ 2199.7810250000  5533.8525767700  14501.3382962825  39086.4884105844
#    107548.3362059714]
#  [ 5533.8525767700  14501.3382962825  39086.4884105844  107548.3362059714
#    300624.1065961840]]
# Matrix B:
# [[ 1.3908700000]
#  [-126.6414295000]
#  [-378.8756895490]
#  [-952.3241035315]
#  [-2308.9705341355]]
# Matrix X for the model
#
# [[-0.4078947434]
#  [ 5.3320982003]
#  [-5.7717920574]
#  [ 1.8151940071]
#  [-0.1563291564]]
# Mean Square Error for 4Degree MODEL is :: 0.050025218416461195
# Model for train Data
# Model for testing Data

# %% [markdown]
# ## Now Fit The 5 degree Model

# %%
#Your code Here
m_int = len(x_train)#to get int no of x values 
sum_x = np.sum(x_train)#summation of x
sum_x_square = np.sum(x_train ** 2)#summation of x2
sum_x_cube = np.sum(x_train ** 3)#summation of x3
sum_x_tetra = np.sum(x_train ** 4)#summation of x4
sum_x_penta = np.sum(x_train ** 5)#summation of x5
sum_x_sixz = np.sum(x_train ** 6)#summation of x6
sum_x_sev = np.sum(x_train ** 7)#summation of x7
sum_x_eight = np.sum(x_train ** 8)#summation of x8
sum_x_nine = np.sum(x_train ** 9)#summation of x9
sum_x_ten = np.sum(x_train ** 10)#summation of x10
sum_y = np.sum(y_train)#summation of y
sum_x_y = np.sum(x_train * y_train)#summation of y and x
sum_x_square_y = np.sum(y_train * (x_train ** 2))#summation of y and x^2
sum_x_cube_y = np.sum(y_train * (x_train ** 3))#summation of y and x^3
sum_x_tetra_y = np.sum(y_train * (x_train ** 4))#summation of y and x^4
sum_x_penta_y = np.sum(y_train * (x_train ** 5))#summation of y and x^5
# Constructing matrices A
matrixA5 = np.array([[m_int, sum_x, sum_x_square, sum_x_cube,sum_x_tetra,sum_x_penta],
                     [sum_x, sum_x_square, sum_x_cube, sum_x_tetra,sum_x_penta,sum_x_sixz],
                     [sum_x_square, sum_x_cube, sum_x_tetra, sum_x_penta,sum_x_sixz,sum_x_sev],
                     [sum_x_cube, sum_x_tetra, sum_x_penta, sum_x_sixz,sum_x_sev,sum_x_eight],
                     [sum_x_tetra, sum_x_penta, sum_x_sixz,sum_x_sev,sum_x_eight,sum_x_nine],
                     [sum_x_penta, sum_x_sixz,sum_x_sev,sum_x_eight,sum_x_nine,sum_x_ten]])
#Constructing matrice B
matrixB5 = np.array([[sum_y], [sum_x_y], [sum_x_square_y], [sum_x_cube_y],[sum_x_tetra_y], [sum_x_penta_y]]) 

# Print matrices with desired formatting
np.set_printoptions(formatter={'float': '{: 0.10f}'.format})
print('Matrix A:')
print(matrixA5)
print('Matrix B:')
print(matrixB5)



#A^-1B
inverse= np.linalg.inv(matrixA5)#to find inverse by using numpy functionality
values = np.dot(inverse,matrixB5)#A^-1B
print("Matrix X for the  model")
print()
print(values)#give thetas values





test_r = pd.read_csv("testRegression.csv")#read file
x_test = np.array(test_r['X'])#store column data in numpy array
y_test = np.array(test_r['R'])#store column data in numpy array
xx = x_test.reshape(-1,1)#2d 
O = values[0]#access 0index
o1 = values[1]#access 1index
o2 = values[2]#access 2index
o3 = values[3]#access 3index
o4 = values[4]#access 4index
o5 = values[5]#access 5index
yt = np.dot(xx,o1)#0_1 * x
ss = np.square(xx)#x^2
yt2 = np.dot(ss,o2)#0_2 * x^2
cc = np.power(xx,3)#x^3
yt3 = np.dot(cc,o3)#0_3 * x^3
tt = np.power(xx,4)#x^4
yt4 =np.dot(tt,o4)#0_4* x^4
pp = np.power(xx,5)#x^5
yt5 = np.dot(pp,o5)#0_5 * x^5
y_predicted = O + yt + yt2 +yt3 +yt4+yt5# y= 0+0_1 * x+0_2 * x^2+0_3 * x^3+0_4 * x^4+0_5 * x^5
m = np.shape(x_test)# to get the x len or u can say number of rows to get numbeer of x values
int_mm = int(m[0])# to get int of touple bcz shape function returns touple
y_actual = y_test
mean_square = np.dot(y_actual-y_predicted,y_actual-y_predicted)*(1/int_mm)#formula to find msq
print("Mean Square Error for 5Degree MODEL is ::",mean_square)

plt.scatter(x_train,y_train,color='pink')#to draw sactterplot
plt.plot(x_test,y_predicted,color='red')#to draw linear regression line
plt.xlabel('X_axis')# just to reppresent x axis
plt.ylabel('Y_axis')# just to reppresent y axis
print('Model for train Data')
plt.show()#to represent
plt.scatter(x_test,y_test,color='purple')#to draw sactterplot
plt.plot(x_test,y_predicted,color='red')#to draw linear regression line
plt.xlabel('X_axis')# just to reppresent x axis
plt.ylabel('Y_axis')# just to reppresent y axis
print('Model for testing Data')
plt.show()
# Out:
# Matrix A:
# [[ 283.0000000000  444.9500000000  932.7465000000  2199.7810250000
#    5533.8525767700  14501.3382962825]
#  [ 444.9500000000  932.7465000000  2199.7810250000  5533.8525767700
#    14501.3382962825  39086.4884105844]
#  [ 932.7465000000  2199.7810250000  5533.8525767700  14501.3382962825
#    39086.4884105844  107548.3362059714]
#  [ 2199.7810250000  5533.8525767700  14501.3382962825  39086.4884105844
#    107548.3362059714  300624.1065961840]
#  [ 5533.8525767700  14501.3382962825  39086.4884105844  107548.3362059714
#    300624.1065961840  850829.6054676272]
#  [ 14501.3382962825  39086.4884105844  107548.3362059714
#    300624.1065961840  850829.6054676272  2432371.1806549490]]
# Matrix B:
# [[ 1.3908700000]
#  [-126.6414295000]
#  [-378.8756895490]
#  [-952.3241035315]
#  [-2308.9705341355]
#  [-5575.0063668163]]
# Matrix X for the  model
#
# [[-0.1513545313]
#  [ 2.8971397187]
#  [-0.3624233547]
#  [-2.7667417500]
#  [ 1.4816117279]
#  [-0.2082293243]]
# ...

# %% [markdown]
# ## Now Fit The 6 degree Model

# %%
#Your code Here

m_int = len(x_train)
sum_x = np.sum(x_train)
sum_x_square = np.sum(x_train ** 2)#summation of x^2
sum_x_cube = np.sum(x_train ** 3)#summation of x^3
sum_x_tetra = np.sum(x_train ** 4)#summation of x^4
sum_x_penta = np.sum(x_train ** 5)#summation of x^5
sum_x_sixz = np.sum(x_train ** 6)#summation of x^6
sum_x_sev = np.sum(x_train ** 7)#summation of x^7
sum_x_eight = np.sum(x_train ** 8)#summation of x^8
sum_x_nine = np.sum(x_train ** 9)#summation of x^9
sum_x_ten = np.sum(x_train ** 10)#summation of x^10
sum_x_eleven = np.sum(x_train ** 11)#summation of x^11
sum_x_twel = np.sum(x_train ** 12)#summation of x^12
sum_y = np.sum(y_train)#summation of y
sum_x_y = np.sum(x_train * y_train)#summation of x and y
sum_x_square_y = np.sum(y_train * (x_train ** 2))#summation of y and x^2
sum_x_cube_y = np.sum(y_train * (x_train ** 3))#summation of y and x^3
sum_x_tetra_y = np.sum(y_train * (x_train ** 4))#summation of y and x^4
sum_x_penta_y = np.sum(y_train * (x_train ** 5))#summation of y and x^5
sum_x_sixa_y = np.sum(y_train * (x_train ** 6))#summation of y and x^6

# Constructing matrice A 
matrixA6 = np.array([[m_int, sum_x, sum_x_square, sum_x_cube,sum_x_tetra,sum_x_penta,sum_x_sixz],
                     [sum_x, sum_x_square, sum_x_cube, sum_x_tetra,sum_x_penta,sum_x_sixz,sum_x_sev],
                     [sum_x_square, sum_x_cube, sum_x_tetra, sum_x_penta,sum_x_sixz,sum_x_sev,sum_x_eight],
                     [sum_x_cube, sum_x_tetra, sum_x_penta, sum_x_sixz,sum_x_sev,sum_x_eight,sum_x_nine],
                     [sum_x_tetra, sum_x_penta, sum_x_sixz,sum_x_sev,sum_x_eight,sum_x_nine,sum_x_ten],
                     [sum_x_penta, sum_x_sixz,sum_x_sev,sum_x_eight,sum_x_nine,sum_x_ten,sum_x_eleven],
                     [sum_x_sixz,sum_x_sev,sum_x_eight,sum_x_nine,sum_x_ten,sum_x_eleven,sum_x_twel]])
#Constructing matrice B

matrixB6 = np.array([[sum_y], [sum_x_y], [sum_x_square_y], [sum_x_cube_y],[sum_x_tetra_y], [sum_x_penta_y],[sum_x_sixa_y]]) 

# Print matrices with desired formatting
np.set_printoptions(formatter={'float': '{: 0.10f}'.format})
print('Matrix A:')
print(matrixA6)
print('Matrix B:')
print(matrixB6)



#A^-1B
inverse= np.linalg.inv(matrixA6)#inverse of 
values = np.dot(inverse,matrixB6)#A^-1B
print("Matrix X for the  model")
print()
print(values)#print tehtas values





test_r = pd.read_csv("testRegression.csv")#read file
x_test = np.array(test_r['X'])#store column data in numpy array
y_test = np.array(test_r['R'])#store column data in numpy array
xx = x_test.reshape(-1,1)#2d dimension
O = values[0]#access 0index
o1 = values[1]#access 1index
o2 = values[2]#access 2index
o3 = values[3]#access 3index
o4 = values[4]#access 4index
o5 = values[5]#access 5index
o6 = values[6]#access 6index
yt = np.dot(xx,o1)#0_1 * x
ss = np.square(xx)#x^2
yt2 = np.dot(ss,o2)#0_2 * x^2
cc = np.power(xx,3)#x^3
yt3 = np.dot(cc,o3)#0_3 * x^3
tt = np.power(xx,4)#x^4
yt4 =np.dot(tt,o4)#0_4* x^4
pp = np.power(xx,5)#x^5
yt5 =np.dot(pp,o5)#0_5 * x^5
sii = np.power(xx,6)#x^6
yt6 =np.dot(sii,o6)#0_6 * x^6
y_predicted = O + yt + yt2 +yt3 +yt4+yt5+yt6# y= 0+0_1 * x+0_2 * x^2+0_3 * x^3+0_4 * x^4+0_5 * x^5+0_6 * x^6
m = np.shape(x_test)# to get the x len or u can say number of rows to get numbeer of x values
int_mm = int(m[0])# to get int of touple bcz shape function returns touple
y_actual = y_test
mean_square = np.dot(y_actual-y_predicted,y_actual-y_predicted)*(1/int_mm)#formula to find msq
print("Mean Square Error for  6Degree MODEL is ::",mean_square)

plt.scatter(x_train,y_train,color='pink')# to draw scatter plot
plt.plot(x_test,y_predicted,color='red')# to draw linear regression line 
plt.xlabel('X_axis')# just to reppresent x axis
plt.ylabel('Y_axis')# just to reppresent y axis
print('Model for train Data')
plt.show()
plt.scatter(x_test,y_test,color='purple')# to draw scatter plot
plt.plot(x_test,y_predicted,color='red')# to draw linear regression line 
plt.xlabel('X_axis')# just to reppresent x axis
plt.ylabel('Y_axis')# just to reppresent y axis
print('Model for testing Data')
plt.show()
# Out:
# Matrix A:
# [[ 283.0000000000  444.9500000000  932.7465000000  2199.7810250000
#    5533.8525767700  14501.3382962825  39086.4884105844]
#  [ 444.9500000000  932.7465000000  2199.7810250000  5533.8525767700
#    14501.3382962825  39086.4884105844  107548.3362059714]
#  [ 932.7465000000  2199.7810250000  5533.8525767700  14501.3382962825
#    39086.4884105844  107548.3362059714  300624.1065961840]
#  [ 2199.7810250000  5533.8525767700  14501.3382962825  39086.4884105844
#    107548.3362059714  300624.1065961840  850829.6054676272]
#  [ 5533.8525767700  14501.3382962825  39086.4884105844  107548.3362059714
#    300624.1065961840  850829.6054676272  2432371.1806549490]
#  [ 14501.3382962825  39086.4884105844  107548.3362059714
#    300624.1065961840  850829.6054676272  2432371.1806549490
#    7011725.3643943416]
#  [ 39086.4884105844  107548.3362059714  300624.1065961840
#    850829.6054676272  2432371.1806549490  7011725.3643943416
#    20354014.2398018390]]
# Matrix B:
# ...

# %% [markdown]
# ### Comment on the results by comparing all of your models

# %% [markdown]
# Mean Square Error for LINEAR MODEL is :: 0.3159321720459774
# Mean Square Error for Quadratic MODEL is :: 0.32604179594962857
# Mean Square Error for Cubic MODEL is::  0.05154205769095602
# Mean Square Error for 4Degree MODEL is :: 0.050025218416461195
# Mean Square Error for 5Degree MODEL is :: 0.04420677426857728
# Mean Square Error for 6Degree MODEL is :: 0.04450867582834679
# AS 5degree model has lowest Mean Square Error value so the best to use in this case is 5degree model beacause lower the MSE value increases the goodness of the model.So the MSE and Best model has inverse relation.
